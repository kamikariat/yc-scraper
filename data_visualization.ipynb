# %%
import pandas as pd

# %%
df = pd.read_csv('output/output.csv')

# %%
df
# Out:
#       company_id            company_name  \
# 0          29162                    Flex
# 1          29159            Healthtech 1
# 2          29178                 Lantern
# 3          29158  Feanix Biotechnologies
# 4          29157             Orbio Earth
# ...          ...                     ...
# 5782         374               TextPayMe
# 5783         373                   Loopt
# 5784         380                Infogami
# 5785         377                  Memamp
# 5786         376                 Simmery
#
#                                       short_description  \
# 0                           Stripe for HSA/FSA payments
# 1         Automating repetitive processes in healthcare
# 2     PostgreSQL vector database extension to build ...
# 3     Combining Genetic Testing and Breeding Advisin...
# 4            Tracking methane emissions with satellites
# ...                                                 ...
# 5782                                                NaN
# ...

# %%
df.head()
# Out:
#    company_id            company_name  \
# 0       29162                    Flex
# 1       29159            Healthtech 1
# 2       29178                 Lantern
# 3       29158  Feanix Biotechnologies
# 4       29157             Orbio Earth
#
#                                    short_description  \
# 0                        Stripe for HSA/FSA payments
# 1      Automating repetitive processes in healthcare
# 2  PostgreSQL vector database extension to build ...
# 3  Combining Genetic Testing and Breeding Advisin...
# 4         Tracking methane emissions with satellites
#
#                                     long_description batch  status  \
# 0  Flex is a payment platform for businesses to a...   S23  Active
# 1   Healthtech-1 automates repetitive processes f...   S23  Active
# 2                                                NaN   W24  Active
# 3  Feanix is a trailblazing force in the trillion...   S23  Active
# 4  Orbio Earth has developed a software platform ...   S23  Active
#
# ...

# %%
filtered_df = df[df['location'] == 'San Francisco']

# %%
filtered_df
# Out:
#       company_id  company_name  \
# 0          29162          Flex
# 5          29156     CodeStory
# 8          29152     Taylor AI
# 9          29134  Flair Health
# 10         29137       TrendUp
# ...          ...           ...
# 5764         355         Xobni
# 5769         361      Shoutfit
# 5775         367      Clustrix
# 5779         379        Reddit
# 5781         375    Clickfacts
#
#                                       short_description  \
# 0                           Stripe for HSA/FSA payments
# 5              CodeStory is an AI powered mod of VSCode
# 8     Helping enterprises fine-tune open-source larg...
# 9     Tackling chronic disease through precise lifes...
# 10        AI tools to help you go viral on any platform
# ...                                                 ...
# 5764                                                NaN
# 5769                                                NaN
# 5775                                                NaN
# ...

# %%
filtered_df = df[df['year_founded'] > 2021]
